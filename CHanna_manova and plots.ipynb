# %%
import pandas as pd
import researchpy as rp
from statsmodels.multivariate.manova import MANOVA
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel (r'C:\Users\karti\data.xlsx',sheet_name='Sheet1')

df.head(2)
# Out:
#   Storage  Time  Moisture    TSS  Protein  Glucose  Lactose     Fat  \
# 0     8°C     0     57.54  42.46   16.125    0.158    2.056  22.137
# 1     8°C     0     55.85  44.15   16.344    0.162    2.156  23.386
#
#    Titrable_acidity  Cocci  Coliform  Lactobacillus  Yeast_Mould   TPC    Ash
# 0              0.28    0.0       0.0           0.35          0.0  0.40  1.834
# 1              0.29    0.0       0.0           0.00          0.0  0.12  2.012

# %%
print(df.isnull().values.any())
# Out:
# False

# %%
SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
g_moisture = sns.catplot(x="Time", y="Moisture",
               col="Storage", col_wrap=3, 
                data=df,  kind="box", legend=False,
                height=3, aspect=1.3);
g_moisture.set(xlabel ="Time (hour)", ylabel = "Moisture (%)",  )
g_moisture.set_titles("{col_name} {col_var}") 
plt.savefig("moisture.png", dpi=1200, facecolor='w',  
               orientation= 'landscape', format='png', transparent=True, bbox_inches=None, pad_inches=0.5,  metadata=None)

# %%
g_TSS = sns.catplot(x="Time", y="TSS",
               col="Storage", col_wrap=3, 
                data=df,  kind="box", legend=False,
                height=3, aspect=1.3);
g_TSS.set(xlabel ="Time (hour)", ylabel = "TSS (%)",  )
g_TSS.set_titles("{col_name} {col_var}") 
plt.savefig("TSS.png", dpi=1200, facecolor='w',  
               orientation= 'landscape', format='png', transparent=True, bbox_inches=None, pad_inches=0.5,  metadata=None)

# %%
g_Protein = sns.catplot(x="Time", y="Protein",
               col="Storage", col_wrap=3, 
                data=df,  kind="box", legend=False,
                height=3, aspect=1.3);
g_Protein.set(xlabel ="Time (hour)", ylabel = "Protein (%)",  )
g_Protein.set_titles("{col_name} {col_var}") 
plt.savefig("Protein.png", dpi=1200, facecolor='w',  
               orientation= 'landscape', format='png', transparent=True, bbox_inches=None, pad_inches=0.5,  metadata=None)

# %%
g_moisture = sns.catplot(x="Time", y="Glucose",
               col="Storage", col_wrap=3, 
                data=df,  kind="box", legend=False,
                height=3, aspect=1.3);
g_moisture.set(xlabel ="Time (hour)", ylabel = "Total reducing sugars (%)",  )
g_moisture.set_titles("{col_name} {col_var}") 
plt.savefig("Glucose.png", dpi=1200, facecolor='w',  
               orientation= 'landscape', format='png', transparent=True, bbox_inches=None, pad_inches=0.5,  metadata=None)

# %%
g_Lactose = sns.catplot(x="Time", y="Lactose",
               col="Storage", col_wrap=3, 
                data=df,  kind="box", legend=False,
                height=3, aspect=1.3);
g_Lactose.set(xlabel ="Time (hour)", ylabel = "Lactose (%)",  )
g_Lactose.set_titles("{col_name} {col_var}") 
plt.savefig("Lactose.png", dpi=1200, facecolor='w',  
               orientation= 'landscape', format='png', transparent=True, bbox_inches=None, pad_inches=0.5,  metadata=None)

# %%
g_Fat = sns.catplot(x="Time", y="Fat",
               col="Storage", col_wrap=3, 
                data=df,  kind="box", legend=False,
                height=3, aspect=1.3);
g_Fat.set(xlabel ="Time (hour)", ylabel = "Fat (%)",  )
g_Fat.set_titles("{col_name} {col_var}") 
plt.savefig("Fat.png", dpi=1200, facecolor='w',  
               orientation= 'landscape', format='png', transparent=True, bbox_inches=None, pad_inches=0.5,  metadata=None)

# %%
g_Titrable_acidity = sns.catplot(x="Time", y="Titrable_acidity",
               col="Storage", col_wrap=3, 
                data=df,  kind="box", legend=False,
                height=3, aspect=1.3);
g_Titrable_acidity.set(xlabel ="Time (hour)", ylabel = "Titrable acidity ",  )
g_Titrable_acidity.set_titles("{col_name} {col_var}") 
plt.savefig("Titrable_acidity.png", dpi=1200, facecolor='w',  
               orientation= 'landscape', format='png', transparent=True, bbox_inches=None, pad_inches=0.5,  metadata=None)

# %%
g_Ash = sns.catplot(x="Time", y="Ash",
               col="Storage", col_wrap=3, 
                data=df,  kind="box", legend=False,
                height=3, aspect=1.3);
g_Ash.set(xlabel ="Time (hour)", ylabel = "Ash (%) ",  )
g_Ash.set_titles("{col_name} {col_var}") 
plt.savefig("Ash.png", dpi=1200, facecolor='w',  
               orientation= 'landscape', format='png', transparent=True, bbox_inches=None, pad_inches=0.5,  metadata=None)

# %%
df1=pd.read_excel (r'C:\Users\karti\data.xlsx',sheet_name='Sheet2')


df1.head(2)
# Out:
#   Immersed_in_whey Temperature  Time  Moisture    TSS  Protein  Glucose  \
# 0               NO         8°C     0     57.54  42.46   16.125    0.158
# 1               NO         8°C     0     55.85  44.15   16.344    0.162
#
#    Lactose     Fat  Titrable_acidity  Cocci  Coliform  Lactobacillus  \
# 0    2.056  22.137              0.28    0.0       0.0           0.35
# 1    2.156  23.386              0.29    0.0       0.0           0.00
#
#    Yeast_Mould   TPC    Ash
# 0          0.0  0.40  1.834
# 1          0.0  0.12  2.012

# %%
maov=MANOVA.from_formula('Moisture + TSS + Protein + Glucose + Lactose + Fat + Titrable_acidity + Cocci + Coliform + Lactobacillus + Yeast_Mould + TPC + Ash ~ Immersed_in_whey + Temperature + Time', data=df1)

# %%
print(maov.mv_test())
# Out:
#                                 Multivariate linear model
# ...
#
# ------------------------------------------------------------------------------------------
#        Intercept               Value          Num DF  Den DF         F Value        Pr > F
# ------------------------------------------------------------------------------------------
#           Wilks' lambda               0.0000 13.0000 173.0000 2853929434194477.0000 0.0000
#          Pillai's trace               1.0000 13.0000 173.0000 2853929434194477.0000 0.0000
#  Hotelling-Lawley trace 214457125112879.7500 13.0000 173.0000 2853929434194476.5000 0.0000
#     Roy's greatest root 214457125112879.7500 13.0000 173.0000 2853929434194477.0000 0.0000
# ------------------------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------
# ...

# %%
maov1=MANOVA.from_formula('Cocci + Coliform + Lactobacillus + Yeast_Mould + TPC ~ Immersed_in_whey + Temperature + Time', data=df1)

# %%
print(maov1.mv_test())
# Out:
#                   Multivariate linear model
# ...
#
# --------------------------------------------------------------
#         Intercept        Value  Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#            Wilks' lambda 0.8604 5.0000 181.0000  5.8738 0.0000
#           Pillai's trace 0.1396 5.0000 181.0000  5.8738 0.0000
#   Hotelling-Lawley trace 0.1623 5.0000 181.0000  5.8738 0.0000
#      Roy's greatest root 0.1623 5.0000 181.0000  5.8738 0.0000
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#     Immersed_in_whey    Value   Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#           Wilks' lambda 0.9183 10.0000 362.0000  1.5752 0.1120
#          Pillai's trace 0.0831 10.0000 364.0000  1.5778 0.1112
#  Hotelling-Lawley trace 0.0874 10.0000 268.7645  1.5756 0.1137
# ...

# %%
maov2=MANOVA.from_formula('Cocci + TPC ~ Immersed_in_whey + Temperature + Time', data=df1)

# %%
print(maov2.mv_test())
# Out:
#                   Multivariate linear model
# ...
#
# --------------------------------------------------------------
#         Intercept        Value  Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#            Wilks' lambda 0.9548 2.0000 184.0000  4.3584 0.0141
#           Pillai's trace 0.0452 2.0000 184.0000  4.3584 0.0141
#   Hotelling-Lawley trace 0.0474 2.0000 184.0000  4.3584 0.0141
#      Roy's greatest root 0.0474 2.0000 184.0000  4.3584 0.0141
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#      Immersed_in_whey    Value  Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#            Wilks' lambda 0.9975 4.0000 368.0000  0.1171 0.9764
#           Pillai's trace 0.0025 4.0000 370.0000  0.1177 0.9762
#   Hotelling-Lawley trace 0.0025 4.0000 219.7642  0.1169 0.9764
# ...

# %%
maov3=MANOVA.from_formula('Coliform  + TPC ~ Immersed_in_whey + Temperature + Time', data=df1)

# %%
print(maov3.mv_test())
# Out:
#                   Multivariate linear model
# ...
#
# --------------------------------------------------------------
#         Intercept        Value  Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#            Wilks' lambda 0.8713 2.0000 184.0000 13.5937 0.0000
#           Pillai's trace 0.1287 2.0000 184.0000 13.5937 0.0000
#   Hotelling-Lawley trace 0.1478 2.0000 184.0000 13.5937 0.0000
#      Roy's greatest root 0.1478 2.0000 184.0000 13.5937 0.0000
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#      Immersed_in_whey    Value  Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#            Wilks' lambda 0.9667 4.0000 368.0000  1.5699 0.1817
#           Pillai's trace 0.0333 4.0000 370.0000  1.5658 0.1828
#   Hotelling-Lawley trace 0.0344 4.0000 219.7642  1.5796 0.1807
# ...

# %%
maov4=MANOVA.from_formula('Lactobacillus  + TPC ~ Immersed_in_whey + Temperature + Time', data=df1)
print(maov4.mv_test())
# Out:
#                   Multivariate linear model
# ...
#
# --------------------------------------------------------------
#         Intercept        Value  Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#            Wilks' lambda 0.9904 2.0000 184.0000  0.8898 0.4125
#           Pillai's trace 0.0096 2.0000 184.0000  0.8898 0.4125
#   Hotelling-Lawley trace 0.0097 2.0000 184.0000  0.8898 0.4125
#      Roy's greatest root 0.0097 2.0000 184.0000  0.8898 0.4125
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#      Immersed_in_whey    Value  Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#            Wilks' lambda 0.9718 4.0000 368.0000  1.3261 0.2597
#           Pillai's trace 0.0282 4.0000 370.0000  1.3250 0.2601
#   Hotelling-Lawley trace 0.0290 4.0000 219.7642  1.3319 0.2590
# ...

# %%
maov5=MANOVA.from_formula('Yeast_Mould   + TPC ~ Immersed_in_whey + Temperature + Time', data=df1)
print(maov5.mv_test())
# Out:
#                   Multivariate linear model
# ...
#
# --------------------------------------------------------------
#         Intercept        Value  Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#            Wilks' lambda 0.9693 2.0000 184.0000  2.9173 0.0566
#           Pillai's trace 0.0307 2.0000 184.0000  2.9173 0.0566
#   Hotelling-Lawley trace 0.0317 2.0000 184.0000  2.9173 0.0566
#      Roy's greatest root 0.0317 2.0000 184.0000  2.9173 0.0566
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#      Immersed_in_whey    Value  Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#            Wilks' lambda 0.9921 4.0000 368.0000  0.3677 0.8316
#           Pillai's trace 0.0080 4.0000 370.0000  0.3692 0.8306
#   Hotelling-Lawley trace 0.0080 4.0000 219.7642  0.3675 0.8316
# ...

# %%
df1=pd.read_excel (r'C:\Users\karti\data.xlsx',sheet_name='Sheet2')


df1.head(2)
df2 = df1[['Immersed_in_whey','Time','TTA','TRS','Cocci','Coliform','Lactobacillus','Yeast_Mould','TPC']]

# %%
df2.rename(columns = {'Immersed_in_whey':'Whey'}, inplace = True)
df2.head(2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#   Whey  Time   TTA    TRS  Cocci  Coliform  Lactobacillus  Yeast_Mould   TPC
# 0   NO     0  0.28  0.158    0.0       0.0           0.35          0.0  0.40
# 1   NO     0  0.29  0.162    0.0       0.0           0.00          0.0  0.12

# %%
# prints data that will be plotted
# columns shown here are selected by corr() since
# they are ideal for the plot
print(df2.corr())
  
# plotting correlation heatmap
heat = sns.heatmap(df2.corr(), cmap="YlOrRd", annot=True)
#plt.savefig("Heat.png", dpi=1200, facecolor='w', orientation= 'landscape', format='png', transparent=True, bbox_inches=None, pad_inches=0.5,  metadata=None)
# Out:
#                    Time       TTA       TRS     Cocci  Coliform  \
# Time           1.000000  0.832260 -0.625364  0.775061  0.622856
# TTA            0.832260  1.000000 -0.553784  0.915394  0.856164
# TRS           -0.625364 -0.553784  1.000000 -0.654256 -0.654784
# Cocci          0.775061  0.915394 -0.654256  1.000000  0.924606
# Coliform       0.622856  0.856164 -0.654784  0.924606  1.000000
# Lactobacillus  0.726387  0.911427 -0.665097  0.935257  0.957028
# Yeast_Mould    0.688207  0.867274 -0.678830  0.843101  0.897940
# TPC            0.734872  0.918839 -0.695958  0.950618  0.972549
#
#                Lactobacillus  Yeast_Mould       TPC
# Time                0.726387     0.688207  0.734872
# TTA                 0.911427     0.867274  0.918839
# TRS                -0.665097    -0.678830 -0.695958
# Cocci               0.935257     0.843101  0.950618
# Coliform            0.957028     0.897940  0.972549
# Lactobacillus       1.000000     0.943186  0.987712
# ...

# %%
from matplotlib import rcParams

# %%
#_reg = sns.pairplot(df2, kind="reg", col_wrap=5, 
             #   legend=False,
             #  height=3, aspect=1.3);
#g_Protein.set(xlabel ="Time (hour)", ylabel = "Protein (%)",  )
#g_Protein.set_titles("{col_name} {col_var}") 
#plt.savefig("Protein.png", dpi=1200, facecolor='w',  
               #orientation= 'landscape', format='png', transparent=True, bbox_inches=None, pad_inches=0.5,  metadata=None)
rcParams['figure.figsize'] = 25,10
sns.pairplot(df2, kind="reg", hue="Time")


plt.savefig('regression.png',orientation="landscape", dpi = 1200, facecolor="w", transparent=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20464/1386903631.py in <module>
#      10
#      11
# ---> 12 plt.savefig('regression.png',orientation="landscape", dpi = 1200, facecolor="w", transparent=True)
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
sns.pairplot(df2,  hue="Time")
